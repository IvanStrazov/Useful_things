# %%
import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib import rcParams
rcParams['figure.figsize'] = 8, 5
import seaborn as sns

# %% [markdown]
# # NLP

# %% [markdown]
# ### NLP (Natural Language Processing) - обработка естественного языка
#
# ### CL (Computational Linguistics) - вычислительная лингвистика

# %% [markdown]
# # Методы кодирования текста

# %% [markdown]
# ## 1) One-hot representation (унитарное кодирование)
#
# Представление текста в виде вектора, размерностью совпадающего с используемым словарем. Значений 1 обозначает наличие слова в тексте, 0 - отсутствие.

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = ['Time flies flies like an arrow.', 'Fruit flies like a banana']
vocab = ['an', 'arrow', 'banana', 'flies', 'fruit', 'like', 'time']
one_hot_vectorizer = CountVectorizer(binary=True)
one_hot = one_hot_vectorizer.fit_transform(corpus).toarray()
sns.heatmap(one_hot, annot=True,
            cbar=False, xticklabels=vocab, 
            yticklabels=['Sentense %i'%i for i in (1, 2)]);

# %% [markdown]
# ## 2) TF-представление (Term Frequency)
#
# Отличается заменой (0,1) на количество вхождений TF(w) слова в текст

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = ['Time flies flies like an arrow.', 'Fruit flies like a banana']
vocab = ['an', 'arrow', 'banana', 'flies', 'fruit', 'like', 'time']
one_hot_vectorizer = CountVectorizer(binary=False)
one_hot = one_hot_vectorizer.fit_transform(corpus).toarray()
sns.heatmap(one_hot, annot=True,
            cbar=False, xticklabels=vocab, 
            yticklabels=['Sentense %i'%i for i in (1, 2)]);

# %% [markdown]
# # TF-IDF (Inverse Document Frequency)
#
# Отличается снижением веса распространенных и повышением веса редких лексем.

# %%
from PIL import Image
Image.open('pictures/tfidf.png').resize((400,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x200 at 0x2BCD5780F08>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = ['Time flies like an arrow.', 'Fruit flies like a banana']
vocab = ['an', 'arrow', 'banana', 'flies', 'fruit', 'like', 'time']
tfidf_vectorizer = TfidfVectorizer()
tfidf = tfidf_vectorizer.fit_transform(corpus).toarray()
sns.heatmap(tfidf, annot=True,
            cbar=False, xticklabels=vocab, 
            yticklabels=['Sentense %i'%i for i in (1, 2)]);

# %% [markdown]
# # Tokenization (токенизация)

# %%
# python -m spacy download en_core_web_sm
import spacy
nlp = spacy.load('en_core_web_sm')
text = "Mary? don't slap the green witch"
[str(token) for token in nlp(text.lower())]
# Out:
# ['mary', '?', 'do', "n't", 'slap', 'the', 'green', 'witch']

# %%
from nltk.tokenize import TweetTokenizer
tweet = u"Snow White and the Seven Degrees #MakeAMovieCold@midnight:-)"
tokenizer = TweetTokenizer()
tokenizer.tokenize(tweet.lower())
# Out:
# ['snow',
#  'white',
#  'and',
#  'the',
#  'seven',
#  'degrees',
#  '#makeamoviecold',
#  '@midnight',
#  ':-)']

# %%
import nltk
# nltk.download('punkt')

text = "Backgammon is one of the oldest known board games. Its history can be traced back nearly 5,000 years to archeological discoveries in the Middle East. It is a two player game where each player has fifteen checkers which move between twenty-four points according to the roll of two dice."
sentences = nltk.sent_tokenize(text)
for sentence in sentences:
    print(sentence)
    print()
# Out:
# Backgammon is one of the oldest known board games.
#
# Its history can be traced back nearly 5,000 years to archeological discoveries in the Middle East.
#
# It is a two player game where each player has fifteen checkers which move between twenty-four points according to the roll of two dice.

# %% [markdown]
# # n-граммы
